# %% [markdown]
# # Report Title
# ### Team JUSTFAIR MSU

# %% [markdown]
# ## Abstract
# Short summary about the data and what it tells you about your project.

# %% [markdown]
# ## Data input
# In this section include code that reads in the csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance_matrix

dist_df = pd.read_csv("2022_Project_distance_Matrix.csv")
dist_df
# Out:
#     ARFL  Argonne  Boeing  Delta Dental  Ford  Hope Village  Kellogg's  \
# 0      7        4       9             8     3             0          6
# 1      0        1       3             2     4             8          6
# 2      3        2       1             6     0             8          5
# 3      8        7       3             9     4             5          0
# 4      0        2       1             8     7             3          9
# 5      3        2       0             6     9             7          8
# 6      3        4       2             9     8             6          0
# 7      1        2       5             3     0             6          9
# 8      6        1       0             5     2             9          4
# 9      3        1       2             6     0             8          9
# 10     1        7       8             0     9             6          5
# 11     5        4       3             6     0             7          2
# 12     3        4       6             9     7             2          5
# 13     8        9       7             5     4             1          6
# 14     0        4       1             7     2             8          5
# 15     4        3       6             5     9             1          7
# 16     2        4       1             7     0             8          9
# 17     1        2       5             6     0             9          3
# 18     0        5       9             2     1             3          8
# 19     2        3       1             7     4             6          9
# 20     3        8       7             0     2             4          9
# 21     3        2       1             5     8             7          9
# 22     0        3       1             7     6             9          5
# 23     1        0       3             2     9             8          7
# 24     6        7       8             9     5             3          4
# 25     2        4       0             9     7             8          3
# 26     2        6       8             7     9             5          0
# 27     2        0       1             5     9             4          8
# 28     3        5       0             6     1             8          7
# 29     7        3       9             5     8             0          6
# 30     5        4       6             7     8             1          9
# 31     6        8       3             7     9             0          4
# 32     4        7       6             9     8             0          3
# 33     7        3       8             5     6             2          9
# 34     4        5       9             8     7             1          6
# 35     7        5       9             3     8             0          4
# 36     2        1       0             5     4             8          6
# 37     1        7       3             0     9             6          8
# 38     5        0       1             3     2             4          9
#
#     Neogen  Old Nation  Qside
# 0        2           5      1
# 1        5           7      9
# 2        4           7      9
# 3        6           1      2
# 4        6           4      5
# 5        4           1      5
# 6        5           7      1
# 7        7           8      4
# 8        3           7      8
# 9        4           5      7
# 10       4           3      2
# 11       1           9      8
# 12       8           1      0
# 13       3           0      2
# 14       3           6      9
# 15       8           2      0
# 16       3           5      6
# 17       4           7      8
# 18       4           7      6
# 19       0           5      8
# 20       6           1      5
# 21       0           4      6
# 22       2           4      8
# 23       6           5      4
# 24       0           2      1
# 25       1           5      6
# 26       3           4      1
# 27       6           3      7
# 28       2           9      4
# 29       4           1      2
# 30       3           0      2
# 31       5           2      1
# 32       5           1      2
# 33       4           0      1
# 34       3           0      2
# 35       6           1      2
# 36       3           7      9
# 37       2           5      4
# 38       6           7      8

# %% [markdown]
# ## Data Cleaning
# In this section provide code for converting the raw data into clean and usable data structures (if needed)

# %% [markdown]
# ## Data Modeling
#
# This section that builds a model.  This doesn't have to be all that advanced. You should probably start with some simple statistical models such as an average distance matrix.

# %%
dist_matrix = distance_matrix(dist_df.T, dist_df.T)

print(dist_matrix)

avg_qside = np.mean(dist_matrix[:-1, 9])
print(avg_qside)
# Out:
# [[ 0.         17.69180601 20.59126028 23.70653918 27.01851217 31.76476035
#   29.51270913 20.0748599  27.82085549 29.81610303]
#  [17.69180601  0.         18.30300522 23.89560629 24.75883681 29.63106478
#   29.05167809 20.92844954 27.11088342 29.79932885]
#  [20.59126028 18.30300522  0.         29.15475947 26.83281573 36.5650106
#   29.88310559 21.97726098 32.15587038 35.19943181]
#  [23.70653918 23.89560629 29.15475947  0.         25.8069758  26.92582404
#   27.76688675 24.87971061 26.90724809 27.69476485]
#  [27.01851217 24.75883681 26.83281573 25.8069758   0.         33.48133809
#   28.61817604 23.89560629 34.2636834  34.6554469 ]
#  [31.76476035 29.63106478 36.5650106  26.92582404 33.48133809  0.
#   26.83281573 26.64582519 15.39480432 14.07124728]
#  [29.51270913 29.05167809 29.88310559 27.76688675 28.61817604 26.83281573
#    0.         24.24871131 27.14774392 23.91652149]
#  [20.0748599  20.92844954 21.97726098 24.87971061 23.89560629 26.64582519
#   24.24871131  0.         23.2594067  25.33771892]
#  [27.82085549 27.11088342 32.15587038 26.90724809 34.2636834  15.39480432
#   27.14774392 23.2594067   0.         15.45962483]
#  [29.81610303 29.79932885 35.19943181 27.69476485 34.6554469  14.07124728
#   23.91652149 25.33771892 15.45962483  0.        ]]
# 26.216687551720284

# %% [markdown]
# ## Data Visualization
#
# This section make some graphs visualizing your results.  A distance matrix and/or network graph may be cool.  Think though the best way to show what you learned.

# %%
import networkx as nx
import seaborn as sns

sns.heatmap(dist_matrix, cmap = "bone", xticklabels = dist_df.columns, yticklabels = dist_df.columns)
#plt.bar(range(10), dist_matrix[:, 9])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Conclusion
#
# This should be similar to the abstract but with more details. What can you conclude about your project from this data?
